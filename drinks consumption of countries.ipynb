# %% [markdown]
# # MultiIndex

# %%
import pandas as pd

# %%
data = pd.read_csv('drinks.csv')

# %%
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# # Setting Multiple Column as Index

# %%
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
data.set_index(['continent','country'] , inplace=True)

# %%
data
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
# ...                              ...              ...            ...
# SA        Venezuela              333              100              3
# AS        Vietnam                111                2              1
#           Yemen                    6                0              0
# AF        Zambia                  32               19              4
#           Zimbabwe                64               18              4
#
#                        total_litres_of_pure_alcohol
# continent country
# ...

# %% [markdown]
# # Sorting MultiIndex

# %%
data.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
#
#                        total_litres_of_pure_alcohol
# continent country
# AS        Afghanistan                           0.0
# EU        Albania                               4.9
# AF        Algeria                               0.7
# EU        Andorra                              12.4
# AF        Angola                                5.9

# %%
data.sort_index()
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...

# %%
data.sort_index(ascending=False)
# Out:
#                              beer_servings  spirit_servings  wine_servings  \
# continent country
# SA        Venezuela                    333              100              3
#           Uruguay                      115               35            220
#           Suriname                     128              178              7
#           Peru                         163              160             21
#           Paraguay                     213              117             74
# ...                                    ...              ...            ...
# NaN       Canada                       240              122            100
#           Belize                       263              114              8
#           Barbados                     143              173             36
#           Bahamas                      122              176             51
#           Antigua & Barbuda            102              128             45
#
# ...

# %%
data.sort_index(ascending=True)
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...

# %%
data.sort_index(ascending=[True,False])
# Out:
#                              beer_servings  spirit_servings  wine_servings  \
# continent country
# AF        Zimbabwe                      64               18              4
#           Zambia                        32               19              4
#           Uganda                        45                9              0
#           Tunisia                       51                3             20
#           Togo                          36                2             19
# ...                                    ...              ...            ...
# NaN       Canada                       240              122            100
#           Belize                       263              114              8
#           Barbados                     143              173             36
#           Bahamas                      122              176             51
#           Antigua & Barbuda            102              128             45
#
# ...

# %%
data.sort_index(ascending=[False,True])
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# SA        Argentina                               193               25
#           Bolivia                                 167               41
#           Brazil                                  245              145
#           Chile                                   130              124
#           Colombia                                159               76
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...

# %% [markdown]
# # Index-Meta Information

# %%
data.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
#
#                        total_litres_of_pure_alcohol
# continent country
# AS        Afghanistan                           0.0
# EU        Albania                               4.9
# AF        Algeria                               0.7
# EU        Andorra                              12.4
# AF        Angola                                5.9

# %%
data.index
# Out:
# MultiIndex([('AS',       'Afghanistan'),
#             ('EU',           'Albania'),
#             ('AF',           'Algeria'),
#             ('EU',           'Andorra'),
#             ('AF',            'Angola'),
#             ( nan, 'Antigua & Barbuda'),
#             ('SA',         'Argentina'),
#             ('EU',           'Armenia'),
#             ('OC',         'Australia'),
#             ('EU',           'Austria'),
#             ...
#             ('AF',          'Tanzania'),
#             ( nan,               'USA'),
#             ('SA',           'Uruguay'),
#             ('AS',        'Uzbekistan'),
#             ('OC',           'Vanuatu'),
#             ('SA',         'Venezuela'),
#             ('AS',           'Vietnam'),
#             ('AS',             'Yemen'),
#             ('AF',            'Zambia'),
#             ('AF',          'Zimbabwe')],
#            names=['continent', 'country'], length=193)

# %%
type(data.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
data.index.names
# Out:
# FrozenList(['continent', 'country'])

# %%
data.index[0]
# Out:
# ('AS', 'Afghanistan')

# %%
data.index[2]
# Out:
# ('AF', 'Algeria')

# %%
data.index[2:5]
# Out:
# MultiIndex([('AF', 'Algeria'),
#             ('EU', 'Andorra'),
#             ('AF',  'Angola')],
#            names=['continent', 'country'])

# %%
len(data)
# Out:
# 193

# %%
data.index.get_level_values(0)
# Out:
# Index(['AS', 'EU', 'AF', 'EU', 'AF',  nan, 'SA', 'EU', 'OC', 'EU',
#        ...
#        'AF',  nan, 'SA', 'AS', 'OC', 'SA', 'AS', 'AS', 'AF', 'AF'],
#       dtype='object', name='continent', length=193)

# %%
data.index.get_level_values(1)
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
data.index.get_level_values('country')
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
data.index.get_level_values('continent')
# Out:
# Index(['AS', 'EU', 'AF', 'EU', 'AF',  nan, 'SA', 'EU', 'OC', 'EU',
#        ...
#        'AF',  nan, 'SA', 'AS', 'OC', 'SA', 'AS', 'AS', 'AF', 'AF'],
#       dtype='object', name='continent', length=193)

# %% [markdown]
# # Change Index Names

# %%
data.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
#
#                        total_litres_of_pure_alcohol
# continent country
# AS        Afghanistan                           0.0
# EU        Albania                               4.9
# AF        Algeria                               0.7
# EU        Andorra                              12.4
# AF        Angola                                5.9

# %%
data.index.set_names(['CONTINENT' , 'COUNTRY'])
# Out:
# MultiIndex([('AS',       'Afghanistan'),
#             ('EU',           'Albania'),
#             ('AF',           'Algeria'),
#             ('EU',           'Andorra'),
#             ('AF',            'Angola'),
#             ( nan, 'Antigua & Barbuda'),
#             ('SA',         'Argentina'),
#             ('EU',           'Armenia'),
#             ('OC',         'Australia'),
#             ('EU',           'Austria'),
#             ...
#             ('AF',          'Tanzania'),
#             ( nan,               'USA'),
#             ('SA',           'Uruguay'),
#             ('AS',        'Uzbekistan'),
#             ('OC',           'Vanuatu'),
#             ('SA',         'Venezuela'),
#             ('AS',           'Vietnam'),
#             ('AS',             'Yemen'),
#             ('AF',            'Zambia'),
#             ('AF',          'Zimbabwe')],
#            names=['CONTINENT', 'COUNTRY'], length=193)

# %% [markdown]
# # Fetching data from MultiIndex Dataframe

# %%
data.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
#
#                        total_litres_of_pure_alcohol
# continent country
# AS        Afghanistan                           0.0
# EU        Albania                               4.9
# AF        Algeria                               0.7
# EU        Andorra                              12.4
# AF        Angola                                5.9

# %%
data.loc['AS']
# Out:
#                       beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                       0                0              0
# Bahrain                          42               63              7
# Bangladesh                        0                0              0
# Bhutan                           23                0              0
# Brunei                           31                2              1
# Cambodia                         57               65              1
# China                            79              192              8
# North Korea                       0                0              0
# India                             9              114              0
# Indonesia                         5                1              0
# Iran                              0                0              0
# Iraq                              9                3              0
# Israel                           63               69              9
# ...

# %%
data.loc['AF' , 'Algeria']
# Out:
# beer_servings                   25.0
# spirit_servings                  0.0
# wine_servings                   14.0
# total_litres_of_pure_alcohol     0.7
# Name: (AF, Algeria), dtype: float64

# %%
data.loc[('AF' , 'Algeria') , 'wine_servings' ]
# Out:
# 14.0

# %%
data.iloc[1]
# Out:
# beer_servings                    89.0
# spirit_servings                 132.0
# wine_servings                    54.0
# total_litres_of_pure_alcohol      4.9
# Name: (EU, Albania), dtype: float64

# %%
data.iloc[1 ,[0 ,1 ,3 ]]
# Out:
# beer_servings                    89.0
# spirit_servings                 132.0
# total_litres_of_pure_alcohol      4.9
# Name: (EU, Albania), dtype: float64

# %%
data.ix['AF']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                           beer_servings  spirit_servings  wine_servings  \
# country
# Algeria                              25                0             14
# Angola                              217               57             45
# Benin                                34                4             13
# Botswana                            173               35             35
# Burkina Faso                         25                7              7
# Burundi                              88                0              0
# Cote d'Ivoire                        37                1              7
# ...

# %%
data.ix[1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# beer_servings                    89.0
# spirit_servings                 132.0
# wine_servings                    54.0
# total_litres_of_pure_alcohol      4.9
# Name: (EU, Albania), dtype: float64

# %%
data.ix[('AF' , 'Algeria'),['beer_servings','spirit_servings']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:993: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
# beer_servings      25.0
# spirit_servings     0.0
# Name: (AF, Algeria), dtype: float64

# %%
data.ix[1,2]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:961: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   return getattr(section, self.name)[new_key]
# 54.0

# %%
data.ix[1,[2,3]]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# wine_servings                   54.0
# total_litres_of_pure_alcohol     4.9
# Name: (EU, Albania), dtype: float64

# %% [markdown]
# # Transpose Dataframe

# %%
data.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
#
#                        total_litres_of_pure_alcohol
# continent country
# AS        Afghanistan                           0.0
# EU        Albania                               4.9
# AF        Algeria                               0.7
# EU        Andorra                              12.4
# AF        Angola                                5.9

# %%
data = data.transpose()

# %%
data
# Out:
# continent                             AS      EU      AF      EU     AF  \
# country                      Afghanistan Albania Algeria Andorra Angola
# beer_servings                        0.0    89.0    25.0   245.0  217.0
# spirit_servings                      0.0   132.0     0.0   138.0   57.0
# wine_servings                        0.0    54.0    14.0   312.0   45.0
# total_litres_of_pure_alcohol         0.0     4.9     0.7    12.4    5.9
#
# continent                                  NaN        SA      EU        OC  \
# country                      Antigua & Barbuda Argentina Armenia Australia
# beer_servings                            102.0     193.0    21.0     261.0
# spirit_servings                          128.0      25.0   179.0      72.0
# wine_servings                             45.0     221.0    11.0     212.0
# total_litres_of_pure_alcohol               4.9       8.3     3.8      10.4
#
# continent                         EU  ...       AF    NaN      SA         AS  \
# ...

# %%
data.loc['spirit_servings','AS']
# Out:
# country
# Afghanistan               0.0
# Bahrain                  63.0
# Bangladesh                0.0
# Bhutan                    0.0
# Brunei                    2.0
# Cambodia                 65.0
# China                   192.0
# North Korea               0.0
# India                   114.0
# Indonesia                 1.0
# Iran                      0.0
# Iraq                      3.0
# Israel                   69.0
# Japan                   202.0
# Jordan                   21.0
# Kazakhstan              246.0
# Kuwait                    0.0
# Kyrgyzstan               97.0
# Laos                      0.0
# Lebanon                  55.0
# Malaysia                  4.0
# Maldives                  0.0
# Mongolia                189.0
# Myanmar                   1.0
# Nepal                     6.0
# Oman                     16.0
# Pakistan                  0.0
# Philippines             186.0
# Qatar                    42.0
# South Korea              16.0
# ...

# %%
data.loc['spirit_servings',('AS' , 'Uzbekistan')]
# Out:
# 101.0

# %%
data.loc[('spirit_servings' , 'wine_servings'),('AS' , 'Uzbekistan')]
# Out:
# spirit_servings    101.0
# wine_servings        8.0
# Name: (AS, Uzbekistan), dtype: float64

# %%
data = data.transpose()

# %%
data.swaplevel()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# country     continent
# Afghanistan AS         0.0            0.0              0.0
# Albania     EU         89.0           132.0            54.0
# Algeria     AF         25.0           0.0              14.0
# Andorra     EU         245.0          138.0            312.0
# Angola      AF         217.0          57.0             45.0
# ...                      ...            ...              ...
# Venezuela   SA         333.0          100.0            3.0
# Vietnam     AS         111.0          2.0              1.0
# Yemen       AS         6.0            0.0              0.0
# Zambia      AF         32.0           19.0             4.0
# Zimbabwe    AF         64.0           18.0             4.0
#
#                        total_litres_of_pure_alcohol
# country     continent
# Afghanistan AS         0.0
# Albania     EU         4.9
# Algeria     AF         0.7
# Andorra     EU         12.4
# ...

# %%
data.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan  0.0            0.0              0.0
# EU        Albania      89.0           132.0            54.0
# AF        Algeria      25.0           0.0              14.0
# EU        Andorra      245.0          138.0            312.0
# AF        Angola       217.0          57.0             45.0
#
#                        total_litres_of_pure_alcohol
# continent country
# AS        Afghanistan  0.0
# EU        Albania      4.9
# AF        Algeria      0.7
# EU        Andorra      12.4
# AF        Angola       5.9

# %% [markdown]
# # Unstack and Stack of Data

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
data = pd.read_csv('drinks.csv' , index_col=['country','continent'])

# %%
data.head()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# country     continent
# Afghanistan AS         0              0                0
# Albania     EU         89             132              54
# Algeria     AF         25             0                14
# Andorra     EU         245            138              312
# Angola      AF         217            57               45
#
#                        total_litres_of_pure_alcohol
# country     continent
# Afghanistan AS         0.0
# Albania     EU         4.9
# Algeria     AF         0.7
# Andorra     EU         12.4
# Angola      AF         5.9

# %%
data.stack()
# Out:
# country      continent
# Afghanistan  AS         beer_servings                   0.0
#                         spirit_servings                 0.0
#                         wine_servings                   0.0
#                         total_litres_of_pure_alcohol    0.0
# Albania      EU         beer_servings                   89.0
#                                                         ...
# Zambia       AF         total_litres_of_pure_alcohol    2.5
# Zimbabwe     AF         beer_servings                   64.0
#                         spirit_servings                 18.0
#                         wine_servings                   4.0
#                         total_litres_of_pure_alcohol    4.7
# Length: 772, dtype: float64

# %%
data = data.stack()

# %%
data.head()
# Out:
# country      continent
# Afghanistan  AS         beer_servings                   0.0
#                         spirit_servings                 0.0
#                         wine_servings                   0.0
#                         total_litres_of_pure_alcohol    0.0
# Albania      EU         beer_servings                   89.0
# dtype: float64

# %%
data.unstack()
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# country     continent
# Afghanistan AS         0.0            0.0              0.0
# Albania     EU         89.0           132.0            54.0
# Algeria     AF         25.0           0.0              14.0
# Andorra     EU         245.0          138.0            312.0
# Angola      AF         217.0          57.0             45.0
# ...                      ...            ...              ...
# Venezuela   SA         333.0          100.0            3.0
# Vietnam     AS         111.0          2.0              1.0
# Yemen       AS         6.0            0.0              0.0
# Zambia      AF         32.0           19.0             4.0
# Zimbabwe    AF         64.0           18.0             4.0
#
#                        total_litres_of_pure_alcohol
# country     continent
# Afghanistan AS         0.0
# Albania     EU         4.9
# Algeria     AF         0.7
# Andorra     EU         12.4
# ...

# %%
data.unstack(0)
# Out:
# country                                 Afghanistan  Albania  Algeria  \
# continent
# NaN       beer_servings                NaN          NaN      NaN
#           spirit_servings              NaN          NaN      NaN
#           wine_servings                NaN          NaN      NaN
#           total_litres_of_pure_alcohol NaN          NaN      NaN
# AF        beer_servings                NaN          NaN       25.0
#           spirit_servings              NaN          NaN       0.0
#           wine_servings                NaN          NaN       14.0
#           total_litres_of_pure_alcohol NaN          NaN       0.7
# AS        beer_servings                 0.0         NaN      NaN
#           spirit_servings               0.0         NaN      NaN
#           wine_servings                 0.0         NaN      NaN
#           total_litres_of_pure_alcohol  0.0         NaN      NaN
# EU        beer_servings                NaN           89.0    NaN
# ...

# %%
data.unstack(1)
# Out:
# continent                                 NaN    AF   AS    EU  OC  SA
# country
# Afghanistan beer_servings                NaN  NaN    0.0 NaN   NaN NaN
#             spirit_servings              NaN  NaN    0.0 NaN   NaN NaN
#             wine_servings                NaN  NaN    0.0 NaN   NaN NaN
#             total_litres_of_pure_alcohol NaN  NaN    0.0 NaN   NaN NaN
# Albania     beer_servings                NaN  NaN   NaN   89.0 NaN NaN
# ...                                       ..   ..    ...  ..    ..  ..
# Zambia      total_litres_of_pure_alcohol NaN   2.5  NaN  NaN   NaN NaN
# Zimbabwe    beer_servings                NaN   64.0 NaN  NaN   NaN NaN
#             spirit_servings              NaN   18.0 NaN  NaN   NaN NaN
#             wine_servings                NaN   4.0  NaN  NaN   NaN NaN
#             total_litres_of_pure_alcohol NaN   4.7  NaN  NaN   NaN NaN
#
# [772 rows x 6 columns]

# %%
data.unstack(1).unstack(0)
# Out:
# continent                            NaN                                 \
# country                      Afghanistan Albania Algeria Andorra Angola
# beer_servings                NaN         NaN     NaN     NaN     NaN
# spirit_servings              NaN         NaN     NaN     NaN     NaN
# wine_servings                NaN         NaN     NaN     NaN     NaN
# total_litres_of_pure_alcohol NaN         NaN     NaN     NaN     NaN
#
# continent                                                                   \
# country                      Antigua & Barbuda Argentina Armenia Australia
# beer_servings                 102.0            NaN       NaN     NaN
# spirit_servings               128.0            NaN       NaN     NaN
# wine_servings                 45.0             NaN       NaN     NaN
# total_litres_of_pure_alcohol  4.9              NaN       NaN     NaN
#
# continent                             ...                   SA                 \
# ...

# %%
data.unstack(2)
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# country     continent
# Afghanistan AS         0.0            0.0              0.0
# Albania     EU         89.0           132.0            54.0
# Algeria     AF         25.0           0.0              14.0
# Andorra     EU         245.0          138.0            312.0
# Angola      AF         217.0          57.0             45.0
# ...                      ...            ...              ...
# Venezuela   SA         333.0          100.0            3.0
# Vietnam     AS         111.0          2.0              1.0
# Yemen       AS         6.0            0.0              0.0
# Zambia      AF         32.0           19.0             4.0
# Zimbabwe    AF         64.0           18.0             4.0
#
#                        total_litres_of_pure_alcohol
# country     continent
# Afghanistan AS         0.0
# Albania     EU         4.9
# Algeria     AF         0.7
# Andorra     EU         12.4
# ...

# %%
data.unstack('country')
# Out:
# country                                 Afghanistan  Albania  Algeria  \
# continent
# NaN       beer_servings                NaN          NaN      NaN
#           spirit_servings              NaN          NaN      NaN
#           wine_servings                NaN          NaN      NaN
#           total_litres_of_pure_alcohol NaN          NaN      NaN
# AF        beer_servings                NaN          NaN       25.0
#           spirit_servings              NaN          NaN       0.0
#           wine_servings                NaN          NaN       14.0
#           total_litres_of_pure_alcohol NaN          NaN       0.7
# AS        beer_servings                 0.0         NaN      NaN
#           spirit_servings               0.0         NaN      NaN
#           wine_servings                 0.0         NaN      NaN
#           total_litres_of_pure_alcohol  0.0         NaN      NaN
# EU        beer_servings                NaN           89.0    NaN
# ...

# %%
data.unstack('continent')
# Out:
# continent                                 NaN    AF   AS    EU  OC  SA
# country
# Afghanistan beer_servings                NaN  NaN    0.0 NaN   NaN NaN
#             spirit_servings              NaN  NaN    0.0 NaN   NaN NaN
#             wine_servings                NaN  NaN    0.0 NaN   NaN NaN
#             total_litres_of_pure_alcohol NaN  NaN    0.0 NaN   NaN NaN
# Albania     beer_servings                NaN  NaN   NaN   89.0 NaN NaN
# ...                                       ..   ..    ...  ..    ..  ..
# Zambia      total_litres_of_pure_alcohol NaN   2.5  NaN  NaN   NaN NaN
# Zimbabwe    beer_servings                NaN   64.0 NaN  NaN   NaN NaN
#             spirit_servings              NaN   18.0 NaN  NaN   NaN NaN
#             wine_servings                NaN   4.0  NaN  NaN   NaN NaN
#             total_litres_of_pure_alcohol NaN   4.7  NaN  NaN   NaN NaN
#
# [772 rows x 6 columns]

# %%
data.unstack('continent').unstack()
# Out:
# continent             NaN                                \
#             beer_servings spirit_servings wine_servings
# country
# Afghanistan NaN           NaN             NaN
# Albania     NaN           NaN             NaN
# Algeria     NaN           NaN             NaN
# Andorra     NaN           NaN             NaN
# Angola      NaN           NaN             NaN
# ...          ..            ..              ..
# Venezuela   NaN           NaN             NaN
# Vietnam     NaN           NaN             NaN
# Yemen       NaN           NaN             NaN
# Zambia      NaN           NaN             NaN
# Zimbabwe    NaN           NaN             NaN
#
# continent                                           AF                  \
#             total_litres_of_pure_alcohol beer_servings spirit_servings
# country
# Afghanistan NaN                          NaN           NaN
# Albania     NaN                          NaN           NaN
# ...

# %% [markdown]
# # Pivot and Pivot_table Method

# %%
data = pd.read_csv('drinks.csv')

# %%
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan  0              0                0
# 1  Albania      89             132              54
# 2  Algeria      25             0                14
# 3  Andorra      245            138              312
# 4  Angola       217            57               45
#
#    total_litres_of_pure_alcohol continent
# 0  0.0                           AS
# 1  4.9                           EU
# 2  0.7                           AF
# 3  12.4                          EU
# 4  5.9                           AF

# %%
data.pivot(index='country' , columns='continent' , values=['spirit_servings'])
# Out:
#             spirit_servings
# continent               NaN    AF   AS     EU  OC     SA
# country
# Afghanistan NaN             NaN    0.0 NaN    NaN NaN
# Albania     NaN             NaN   NaN   132.0 NaN NaN
# Algeria     NaN              0.0  NaN  NaN    NaN NaN
# Andorra     NaN             NaN   NaN   138.0 NaN NaN
# Angola      NaN              57.0 NaN  NaN    NaN NaN
# ...          ..              ...   ..   ..     ..  ..
# Venezuela   NaN             NaN   NaN  NaN    NaN  100.0
# Vietnam     NaN             NaN    2.0 NaN    NaN NaN
# Yemen       NaN             NaN    0.0 NaN    NaN NaN
# Zambia      NaN              19.0 NaN  NaN    NaN NaN
# Zimbabwe    NaN              18.0 NaN  NaN    NaN NaN
#
# [193 rows x 6 columns]

# %%
data.pivot(index='country' , columns='continent' , values=['spirit_servings' , 'beer_servings'] , )
# Out:
#             spirit_servings                              beer_servings         \
# continent               NaN    AF   AS     EU  OC     SA           NaN     AF
# country
# Afghanistan NaN             NaN    0.0 NaN    NaN NaN    NaN           NaN
# Albania     NaN             NaN   NaN   132.0 NaN NaN    NaN           NaN
# Algeria     NaN              0.0  NaN  NaN    NaN NaN    NaN            25.0
# Andorra     NaN             NaN   NaN   138.0 NaN NaN    NaN           NaN
# Angola      NaN              57.0 NaN  NaN    NaN NaN    NaN            217.0
# ...          ..              ...   ..   ..     ..  ..     ..             ...
# Venezuela   NaN             NaN   NaN  NaN    NaN  100.0 NaN           NaN
# Vietnam     NaN             NaN    2.0 NaN    NaN NaN    NaN           NaN
# Yemen       NaN             NaN    0.0 NaN    NaN NaN    NaN           NaN
# Zambia      NaN              19.0 NaN  NaN    NaN NaN    NaN            32.0
# ...

# %%
data.pivot_table(index='continent' , values=['spirit_servings','beer_servings'] , aggfunc=['mean'])
# Out:
#                    mean
#           beer_servings spirit_servings
# continent
# AF         61.471698     16.339623
# AS         37.045455     60.840909
# EU         193.777778    132.555556
# OC         89.687500     58.437500
# SA         175.083333    114.750000

# %%
data.pivot_table(index='continent' , values=['spirit_servings','beer_servings'] , aggfunc=['mean' , 'sum' ])
# Out:
#                    mean                           sum
#           beer_servings spirit_servings beer_servings spirit_servings
# continent
# AF         61.471698     16.339623       3258          866
# AS         37.045455     60.840909       1630          2677
# EU         193.777778    132.555556      8720          5965
# OC         89.687500     58.437500       1435          935
# SA         175.083333    114.750000      2101          1377

# %%
data.pivot_table(index='country' , values=['spirit_servings','beer_servings'] , aggfunc=['mean'])
# Out:
#                      mean
#             beer_servings spirit_servings
# country
# Afghanistan  0             0
# Albania      89            132
# Algeria      25            0
# Andorra      245           138
# Angola       217           57
# ...          ..           ..
# Venezuela    333           100
# Vietnam      111           2
# Yemen        6             0
# Zambia       32            19
# Zimbabwe     64            18
#
# [193 rows x 2 columns]
